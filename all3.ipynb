# %% [markdown]
# <a href="https://colab.research.google.com/github/m-tabish/FER2013/blob/main/all3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install necessary libraries

# %%
# !pip install kaggle tensorflow pandas numpy scikit-learn graphviz visualkeras --quiet

# %% [markdown]
# # Import libraries

# %%
import os
import visualkeras
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras import backend as K
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.utils import plot_model
from IPython.display import Image
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model

# %% [markdown]
# # Set up kaggle (Sometimes need to run more than one time)

# %%
import os
from kaggle.api.kaggle_api_extended import KaggleApi
from pathlib import Path

# === STEP 1: Set Kaggle credentials as environment variables ===
os.environ['KAGGLE_USERNAME'] = "mtabish111"
os.environ['KAGGLE_KEY'] = "783de401ee61591142e17dcc6700c505"

# === STEP 2: Initialize and Authenticate Kaggle API ===
api= ""
try:
    api = KaggleApi()

    api.authenticate()
    print("Kaggle API authenticated successfully using environment variables.")
except IOError as e:
    # This will catch the error if the environment variables are not set correctly.
    print(f"Authentication failed: {e}")
    print("Please ensure your KAGGLE_USERNAME and KAGGLE_KEY environment variables are set correctly.")
# Out:
# Kaggle API authenticated successfully using environment variables.

# %% [markdown]
# # Download the dataset and unzip

# %% [markdown]
# ### MY DATA

# %%
from pathlib import Path

# dataset_slug = './'
destination_path = Path('') # Changed destination path to the directory where content should be extracted

# Create the destination directory if it doesn't exist
if not os.path.exists('FER2013'):
  destination_path.mkdir(parents=True, exist_ok=True)

# Download the dataset to the specified destination
# print(f"Unzipping dataset '{dataset_slug}' to '{destination_path}'...")
# Unzipping destination path
# !unzip /content/FER2013_ME.zip -d /content/
print("Unzipping complete.")
# Out:
# unzip:  cannot find or open /content/FER2013_ME.zip, /content/FER2013_ME.zip.zip or /content/FER2013_ME.zip.ZIP.
# Unzipping complete.

# %% [markdown]
# ### DOWNLOAD DATA FROM INTERNET

# %%
dataset_slug = 'msambare/fer2013'
destination_path = Path('FER2013_ME')

# Create the destination directory if it doesn't exist
destination_path.mkdir(parents=True, exist_ok=True)

# Download the dataset to the specified destination
print(f"Downloading dataset '{dataset_slug}' to '{destination_path}'...")
api.dataset_download_files(dataset_slug, path=destination_path, unzip=True)
print("Download complete.")
# Out:
# Downloading dataset 'msambare/fer2013' to 'FER2013_ME'...
# Dataset URL: https://www.kaggle.com/datasets/msambare/fer2013
# Download complete.

# %% [markdown]
#  # Data Preparation & Augmentation

# %%
IMG_SIZE = 48
BATCH_SIZE = 64
train_dir = "/content/FER2013_ME/train"
test_dir = "/content/FER2013_ME/test"

# 1. Create a single generator for both training and validation
#    and add the validation_split argument.
train_val_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    validation_split=0.2
)

# The test data generator remains separate and does not need a split.
test_datagen = ImageDataGenerator(rescale=1.0/255)

# 2. Create the training generator using the 'training' subset
train_generator = train_val_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    color_mode="grayscale",
    class_mode="categorical",
    subset='training' # Specify this is the training subset
)

# 3. Create the validation generator using the 'validation' subset
validation_generator = train_val_datagen.flow_from_directory(
    train_dir, # Use the same directory as the training generator
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    color_mode="grayscale",
    class_mode="categorical",
    subset='validation' # Specify this is the validation subset
)

# 4. The test generator is created from the separate test directory
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    color_mode="grayscale",
    class_mode="categorical"
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # Viewing training images from dataset

# %%
plt.style.use('ggplot')

# Get a batch of images and labels from the train_generator
images, labels = next(train_generator)

plt.figure(figsize=(12, 12))
for i in range(16):  # Displaying the first 16 images
    plt.subplot(4, 4, i + 1)
    # images[i] is expected to have shape (48, 48, 1) for grayscale
    plt.imshow(images[i].reshape((48, 48)), cmap="gray")
    plt.axis('off')
    plt.tight_layout()

plt.show()

# %% [markdown]
# # Print how many samples are in dataset

# %%
print("Train samples:", train_generator.samples)
print("Test samples:", test_generator.samples)
# Out:
# Train samples: 22968
# Test samples: 7178

# %% [markdown]
#  # EARLY STOPPING , CHECKPOINT AND LR

# %%
# Callback function for Plateau
lr_reduction = ReduceLROnPlateau(
    monitor='val_loss',   # Metric to watch
    patience=5,           # Number of epochs with no improvement before reducing
    factor=0.5,           # Multiply learning rate by this factor
    min_lr=1e-7,          # Lower bound for the learning rate
    verbose =1            # Print messages when LR changes
)


# Early Stopping
early_stop = EarlyStopping(
    monitor='val_loss',       # What to monitor
    patience=5,               # Stop after 8 epochs of no improvement
    restore_best_weights=True # Roll back to best model
)


# Define the callback for saving model weights
checkpoint_callback = ModelCheckpoint(
    filepath='model_weights.weights.h5', # Changed the filepath to end with .weights.h5
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

# %% [markdown]
# # Class Imbalance Handling + Checkpointing

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

class_labels = list(train_generator.class_indices.keys())
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(len(class_labels)),
    y=train_generator.classes
)
class_weights = dict(enumerate(class_weights))

# %% [markdown]
# # Define CNN Model

# %% [markdown]
# ### baseline model

# %%
# Image parameters
img_height, img_width = 48, 48
batch_size = 64
initial_lr = 5e-4
weight_decay = 1e-4   # L2
num_classes = 7       # FER2013
epochs = 50

model = Sequential([
    # --- Block 1 (Deeper and Wider) ---
    Conv2D(64, (3, 3), padding='same', input_shape=(img_height, img_width, 1)),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(64, (3, 3), padding='same'), # Added second Conv2D layer
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.3), # Adjusted dropout

    # --- Block 2 (Deeper and Wider) ---
    Conv2D(128, (3, 3), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(128, (3, 3), padding='same'), # Added second Conv2D layer
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.4), # Adjusted dropout

    # --- Block 3 (Deeper and Wider) ---
    Conv2D(256, (3, 3), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(256, (3, 3), padding='same'), # Added second Conv2D layer
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.5), # Adjusted dropout

    # --- Classifier Head ---
    Flatten(),
    Dense(256), # Increased Dense layer size
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),

    # Output Layer
    Dense(train_generator.num_classes, activation='softmax')
])

# Compile with a slightly higher initial learning rate for use with a scheduler
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_30 (Conv2D)              │ (None, 48, 48, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_35          │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_35 (Activation)      │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_31 (Conv2D)              │ (None, 48, 48, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_36          │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_36 (Activation)      │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_32 (Conv2D)              │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_37          │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_37 (Activation)      │ (None, 24, 24, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_33 (Conv2D)              │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_38          │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_38 (Activation)      │ (None, 24, 24, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_21 (Dropout)            │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_34 (Conv2D)              │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_39          │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_39 (Activation)      │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_35 (Conv2D)              │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_40          │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_40 (Activation)      │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_22 (Dropout)            │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │     2,359,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_41          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_41 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_23 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,510,215 (13.39 MB)
#  Trainable params: 3,507,911 (13.38 MB)
#  Non-trainable params: 2,304 (9.00 KB)

# %% [markdown]
# # Training

# %% [markdown]
# ## TRAINING MODEL

# %% [markdown]
# ### Running with model weights

# %%
# Load your saved model
model = load_model("/content/3_model_weights.weights.h5")

EPOCHS = 20

history = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=EPOCHS,
    callbacks =[  lr_reduction ,early_stop, checkpoint_callback],
    class_weight=class_weights
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-478107721.py in <cell line: 0>()
#       1 # Load your saved model
# ----> 2 model = load_model("/content/3_model_weights.weights.h5")
#       3
#       4 EPOCHS = 20
#       5
#
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     194         )
#     195     if str(filepath).endswith((".h5", ".hdf5")):
# --> 196         return legacy_h5_format.load_model_from_hdf5(
#     197             filepath, custom_objects=custom_objects, compile=compile
#     198         )
#
# /usr/local/lib/python3.11/dist-packages/keras/src/legacy/saving/legacy_h5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     123         model_config = f.attrs.get("model_config")
#     124         if model_config is None:
# --> 125             raise ValueError(
#     126                 f"No model config found in the file at {filepath}."
#     127             )
#
# ValueError: No model config found in the file at /content/3_model_weights.weights.h5.

# %% [markdown]
# ### Full training

# %%
EPOCHS = 50

history = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=EPOCHS,
    callbacks =[  lr_reduction ,early_stop, checkpoint_callback],
    class_weight=class_weights
)
# Out:
# Epoch 1/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1620 - loss: 2.3326
# Epoch 1: val_accuracy did not improve from 0.26902
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 46s 87ms/step - accuracy: 0.1620 - loss: 2.3316 - val_accuracy: 0.1697 - val_loss: 2.0531 - learning_rate: 0.0010
# Epoch 2/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.2138 - loss: 1.9621
# Epoch 2: val_accuracy did not improve from 0.26902
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.2138 - loss: 1.9620 - val_accuracy: 0.2184 - val_loss: 2.0459 - learning_rate: 0.0010
# Epoch 3/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.2551 - loss: 1.8454
# Epoch 3: val_accuracy did not improve from 0.26902
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 22s 62ms/step - accuracy: 0.2552 - loss: 1.8452 - val_accuracy: 0.2522 - val_loss: 2.2109 - learning_rate: 0.0010
# Epoch 4/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.3329 - loss: 1.6835
# Epoch 4: val_accuracy improved from 0.26902 to 0.37740, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.3329 - loss: 1.6834 - val_accuracy: 0.3774 - val_loss: 1.5881 - learning_rate: 0.0010
# Epoch 5/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.3759 - loss: 1.5717
# Epoch 5: val_accuracy improved from 0.37740 to 0.41237, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.3759 - loss: 1.5717 - val_accuracy: 0.4124 - val_loss: 1.5684 - learning_rate: 0.0010
# Epoch 6/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.4102 - loss: 1.5005
# Epoch 6: val_accuracy did not improve from 0.41237
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 63ms/step - accuracy: 0.4102 - loss: 1.5004 - val_accuracy: 0.3576 - val_loss: 1.5987 - learning_rate: 0.0010
# Epoch 7/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4400 - loss: 1.4432
# Epoch 7: val_accuracy improved from 0.41237 to 0.43912, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.4401 - loss: 1.4432 - val_accuracy: 0.4391 - val_loss: 1.4331 - learning_rate: 0.0010
# Epoch 8/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4471 - loss: 1.4235
# Epoch 8: val_accuracy improved from 0.43912 to 0.49902, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 25s 70ms/step - accuracy: 0.4471 - loss: 1.4235 - val_accuracy: 0.4990 - val_loss: 1.3194 - learning_rate: 0.0010
# Epoch 9/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4600 - loss: 1.3917
# Epoch 9: val_accuracy did not improve from 0.49902
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 22s 63ms/step - accuracy: 0.4600 - loss: 1.3917 - val_accuracy: 0.4380 - val_loss: 1.5142 - learning_rate: 0.0010
# Epoch 10/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4769 - loss: 1.3665
# Epoch 10: val_accuracy improved from 0.49902 to 0.51728, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 64ms/step - accuracy: 0.4769 - loss: 1.3665 - val_accuracy: 0.5173 - val_loss: 1.2349 - learning_rate: 0.0010
# Epoch 11/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.4896 - loss: 1.3286
# Epoch 11: val_accuracy did not improve from 0.51728
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.4896 - loss: 1.3286 - val_accuracy: 0.4439 - val_loss: 1.4554 - learning_rate: 0.0010
# Epoch 12/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4869 - loss: 1.3128
# Epoch 12: val_accuracy improved from 0.51728 to 0.53859, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.4869 - loss: 1.3128 - val_accuracy: 0.5386 - val_loss: 1.2094 - learning_rate: 0.0010
# Epoch 13/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5061 - loss: 1.2751
# Epoch 13: val_accuracy did not improve from 0.53859
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 22s 61ms/step - accuracy: 0.5061 - loss: 1.2751 - val_accuracy: 0.5187 - val_loss: 1.2683 - learning_rate: 0.0010
# Epoch 14/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5086 - loss: 1.2703
# Epoch 14: val_accuracy did not improve from 0.53859
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 62ms/step - accuracy: 0.5086 - loss: 1.2703 - val_accuracy: 0.5223 - val_loss: 1.2475 - learning_rate: 0.0010
# Epoch 15/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5229 - loss: 1.2240
# Epoch 15: val_accuracy improved from 0.53859 to 0.55642, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.5229 - loss: 1.2240 - val_accuracy: 0.5564 - val_loss: 1.1727 - learning_rate: 0.0010
# Epoch 16/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5132 - loss: 1.2424
# Epoch 16: val_accuracy did not improve from 0.55642
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 22s 61ms/step - accuracy: 0.5133 - loss: 1.2424 - val_accuracy: 0.4992 - val_loss: 1.3257 - learning_rate: 0.0010
# Epoch 17/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5379 - loss: 1.1936
# Epoch 17: val_accuracy did not improve from 0.55642
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 63ms/step - accuracy: 0.5378 - loss: 1.1937 - val_accuracy: 0.5400 - val_loss: 1.2036 - learning_rate: 0.0010
# Epoch 18/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5275 - loss: 1.1993
# Epoch 18: val_accuracy improved from 0.55642 to 0.57843, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.5275 - loss: 1.1993 - val_accuracy: 0.5784 - val_loss: 1.1097 - learning_rate: 0.0010
# Epoch 19/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5361 - loss: 1.1858
# Epoch 19: val_accuracy did not improve from 0.57843
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 25s 69ms/step - accuracy: 0.5361 - loss: 1.1858 - val_accuracy: 0.5641 - val_loss: 1.1536 - learning_rate: 0.0010
# Epoch 20/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5492 - loss: 1.1528
# Epoch 20: val_accuracy did not improve from 0.57843
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 25s 69ms/step - accuracy: 0.5492 - loss: 1.1528 - val_accuracy: 0.5510 - val_loss: 1.1799 - learning_rate: 0.0010
# Epoch 21/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5489 - loss: 1.1597
# Epoch 21: val_accuracy did not improve from 0.57843
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.5489 - loss: 1.1597 - val_accuracy: 0.5514 - val_loss: 1.1881 - learning_rate: 0.0010
# Epoch 22/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5486 - loss: 1.1522
# Epoch 22: val_accuracy improved from 0.57843 to 0.58874, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 22s 62ms/step - accuracy: 0.5486 - loss: 1.1521 - val_accuracy: 0.5887 - val_loss: 1.0752 - learning_rate: 0.0010
# Epoch 23/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5574 - loss: 1.1385
# Epoch 23: val_accuracy did not improve from 0.58874
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 65ms/step - accuracy: 0.5574 - loss: 1.1385 - val_accuracy: 0.5867 - val_loss: 1.0737 - learning_rate: 0.0010
# Epoch 24/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5617 - loss: 1.0983
# Epoch 24: val_accuracy did not improve from 0.58874
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.5617 - loss: 1.0984 - val_accuracy: 0.5435 - val_loss: 1.2244 - learning_rate: 0.0010
# Epoch 25/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5630 - loss: 1.0965
# Epoch 25: val_accuracy improved from 0.58874 to 0.58958, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.5630 - loss: 1.0966 - val_accuracy: 0.5896 - val_loss: 1.0728 - learning_rate: 0.0010
# Epoch 26/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5680 - loss: 1.0935
# Epoch 26: val_accuracy did not improve from 0.58958
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 22s 63ms/step - accuracy: 0.5680 - loss: 1.0935 - val_accuracy: 0.5578 - val_loss: 1.1770 - learning_rate: 0.0010
# Epoch 27/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5617 - loss: 1.0809
# Epoch 27: val_accuracy did not improve from 0.58958
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.5617 - loss: 1.0809 - val_accuracy: 0.5770 - val_loss: 1.1422 - learning_rate: 0.0010
# Epoch 28/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5749 - loss: 1.0689
# Epoch 28: val_accuracy improved from 0.58958 to 0.59348, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 63ms/step - accuracy: 0.5749 - loss: 1.0689 - val_accuracy: 0.5935 - val_loss: 1.0584 - learning_rate: 0.0010
# Epoch 29/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5724 - loss: 1.0676
# Epoch 29: val_accuracy improved from 0.59348 to 0.59473, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.5724 - loss: 1.0676 - val_accuracy: 0.5947 - val_loss: 1.0598 - learning_rate: 0.0010
# Epoch 30/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5822 - loss: 1.0589
# Epoch 30: val_accuracy improved from 0.59473 to 0.61173, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.5822 - loss: 1.0589 - val_accuracy: 0.6117 - val_loss: 1.0226 - learning_rate: 0.0010
# Epoch 31/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5842 - loss: 1.0367
# Epoch 31: val_accuracy did not improve from 0.61173
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 63ms/step - accuracy: 0.5843 - loss: 1.0367 - val_accuracy: 0.6021 - val_loss: 1.0548 - learning_rate: 0.0010
# Epoch 32/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5831 - loss: 1.0325
# Epoch 32: val_accuracy did not improve from 0.61173
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.5831 - loss: 1.0325 - val_accuracy: 0.5872 - val_loss: 1.1237 - learning_rate: 0.0010
# Epoch 33/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5846 - loss: 1.0477
# Epoch 33: val_accuracy did not improve from 0.61173
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.5846 - loss: 1.0476 - val_accuracy: 0.5975 - val_loss: 1.0717 - learning_rate: 0.0010
# Epoch 34/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5932 - loss: 1.0194
# Epoch 34: val_accuracy improved from 0.61173 to 0.61466, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.5932 - loss: 1.0194 - val_accuracy: 0.6147 - val_loss: 1.0232 - learning_rate: 0.0010
# Epoch 35/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5923 - loss: 1.0221
# Epoch 35: val_accuracy improved from 0.61466 to 0.61897, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 65ms/step - accuracy: 0.5923 - loss: 1.0221 - val_accuracy: 0.6190 - val_loss: 1.0155 - learning_rate: 0.0010
# Epoch 36/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5992 - loss: 0.9969
# Epoch 36: val_accuracy improved from 0.61897 to 0.62037, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.5992 - loss: 0.9969 - val_accuracy: 0.6204 - val_loss: 1.0140 - learning_rate: 0.0010
# Epoch 37/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6003 - loss: 0.9881
# Epoch 37: val_accuracy did not improve from 0.62037
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.6003 - loss: 0.9882 - val_accuracy: 0.5974 - val_loss: 1.1040 - learning_rate: 0.0010
# Epoch 38/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5899 - loss: 1.0034
# Epoch 38: val_accuracy did not improve from 0.62037
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.5899 - loss: 1.0034 - val_accuracy: 0.6081 - val_loss: 1.0579 - learning_rate: 0.0010
# Epoch 39/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6083 - loss: 0.9827
# Epoch 39: val_accuracy did not improve from 0.62037
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.6083 - loss: 0.9827 - val_accuracy: 0.6198 - val_loss: 1.0274 - learning_rate: 0.0010
# Epoch 40/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6062 - loss: 0.9688
# Epoch 40: val_accuracy did not improve from 0.62037
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 62ms/step - accuracy: 0.6062 - loss: 0.9689 - val_accuracy: 0.5925 - val_loss: 1.0944 - learning_rate: 0.0010
# Epoch 41/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6017 - loss: 0.9747
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 41: val_accuracy did not improve from 0.62037
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.6017 - loss: 0.9748 - val_accuracy: 0.6199 - val_loss: 1.0213 - learning_rate: 0.0010

# %% [markdown]
# # Metrics : Accuracy, Precision, Recall, F1-score

# %%
def f1_score(y_true, y_pred):
    y_pred = K.round(y_pred)
    tp = K.sum(K.cast(y_true * y_pred, 'float'), axis=0)
    fp = K.sum(K.cast((1-y_true) * y_pred, 'float'), axis=0)
    fn = K.sum(K.cast(y_true * (1-y_pred), 'float'), axis=0)

    precision = tp / (tp + fp + K.epsilon())
    recall = tp / (tp + fn + K.epsilon())

    f1 = 2 * precision * recall / (precision + recall + K.epsilon())
    return K.mean(f1)

# %% [markdown]
# # Classification Report

# %%
# 1. Get the true labels from the validation generator
# The .classes attribute gives the class index for each sample in order.
validation_labels = validation_generator.classes

# 2. Get the model's predictions for the validation set
# It's good practice to reset the generator before predicting
validation_generator.reset()
pred_probs = model.predict(validation_generator)
# Convert prediction probabilities to class labels
validation_pred_labels = np.argmax(pred_probs, axis=1)

# 3. Create the Confusion Matrix
cm = confusion_matrix(validation_labels, validation_pred_labels)
class_names = list(validation_generator.class_indices.keys())

# 4. Plot the confusion matrix for a more visual analysis
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix for Validation Set')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.savefig("results/confusion_matrix.png")
plt.show()

# 5. Print the Classification Report
# This provides precision, recall, and f1-score for each class.
print("Classification Report for Validation Set\n")
print(classification_report(validation_labels, validation_pred_labels, target_names=class_names))
# Saving the metrics in result/ in form of txt but not removing other things
with open('results/metrics.txt', 'w') as f:
    f.write("Classification Report for Validation Set\n")
    f.write(classification_report(validation_labels, validation_pred_labels, target_names=class_names))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step
# Classification Report for Validation Set
#
#               precision    recall  f1-score   support
#
#        angry       0.14      0.16      0.15       799
#      disgust       0.01      0.01      0.01        87
#         fear       0.15      0.13      0.14       819
#        happy       0.25      0.21      0.23      1443
#      neutral       0.16      0.16      0.16       993
#          sad       0.16      0.18      0.17       966
#     surprise       0.11      0.12      0.11       634
#
#     accuracy                           0.16      5741
#    macro avg       0.14      0.14      0.14      5741
# weighted avg       0.17      0.16      0.17      5741

# %% [markdown]
# # Visualizing the model

# %%
# prompt: Write me a code to interactivaly visualize the Neural Network architecture of the above model

if not os.path.exists('results'):
  os.mkdir("results")

model_plot_path = 'results/model_plot.png'
# Generate and save the model plot
plot_model(model, to_file=model_plot_path, show_shapes=True, show_layer_names=True)

# Display the generated image in the notebook
Image(filename=model_plot_path)

# %% [markdown]
# # Saving the Model

# %%
model.save("results/emotion_model.keras")
print("Model saved successfully!")
# Out:
# Model saved successfully!

# %% [markdown]
# # Plotting the graphs (Accuracy/Loss Curves Visualization)

# %% [markdown]
# ### Plot the train and validation loss

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig("results/training_validation_loss.png")
plt.show()

# %% [markdown]
# ### Plot the train and validation accuracy

# %%
# Plot the train and validation accuracy
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, train_acc, 'ro', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig("results/training_validation_accuracy.png")
plt.show()

# %% [markdown]
# # Converting results to zip for download

# %%
import shutil
# ====================
#  ZIP RESULTS
# ====================
shutil.make_archive("results", 'zip', "results")
print("✅ Training complete. Results saved to results.zip")
# Out:
# ✅ Training complete. Results saved to results.zip

# %% [markdown]
# # Converting images to testing data set

# %%
import os
from PIL import Image

# --- SETTINGS ---
input_folder = "my_images"  # folder containing your images (unsorted)
output_folder = "myimages"  # where to save processed images
target_size = (48, 48)  # for FER-style datasets
to_grayscale = True  # set False if you want to keep RGB

# --- CREATE OUTPUT FOLDER IF NOT EXISTS ---
os.makedirs(output_folder, exist_ok=True)

# --- PROCESS IMAGES ---
for i, filename in enumerate(os.listdir(input_folder)):
    if filename.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".gif")):
        img_path = os.path.join(input_folder, filename)
        try:
            img = Image.open(img_path)

            # Convert to grayscale if needed
            if to_grayscale:
                img = img.convert("L")  # "L" = 8-bit pixels, black and white

            # Resize to target size
            img = img.resize(target_size)

            # Save to output folder
            save_path = os.path.join(output_folder, f"img_{i+1}.jpg")
            img.save(save_path)

            print(f"Processed: {filename} → {save_path}")
        except Exception as e:
            print(f"Error processing {filename}: {e}")

print("\n✅ All images processed and saved to:", output_folder)

# %%
from google.colab import runtime
runtime.unassign()
