# %% [markdown]
# <a href="https://colab.research.google.com/github/m-tabish/FER2013/blob/main/baseline_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install necessary libraries

# %%
# !pip install kaggle tensorflow pandas numpy scikit-learn graphviz visualkeras --quiet

# %% [markdown]
# # Import libraries

# %%
import os
import visualkeras
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras import backend as K
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.utils import plot_model
from IPython.display import Image
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# # Set up kaggle (Sometimes need to run more than one time)

# %%
import os
from kaggle.api.kaggle_api_extended import KaggleApi
from pathlib import Path

# === STEP 1: Set Kaggle credentials as environment variables ===
os.environ['KAGGLE_USERNAME'] = "mtabish111"
os.environ['KAGGLE_KEY'] = "783de401ee61591142e17dcc6700c505"

# === STEP 2: Initialize and Authenticate Kaggle API ===
api= ""
try:
    api = KaggleApi()

    api.authenticate()
    print("Kaggle API authenticated successfully using environment variables.")
except IOError as e:
    # This will catch the error if the environment variables are not set correctly.
    print(f"Authentication failed: {e}")
    print("Please ensure your KAGGLE_USERNAME and KAGGLE_KEY environment variables are set correctly.")
# Out:
# Kaggle API authenticated successfully using environment variables.

# %% [markdown]
# # Download the dataset and unzip

# %%
dataset_slug = 'msambare/fer2013'
destination_path = Path('fer2013_data')

# Create the destination directory if it doesn't exist
destination_path.mkdir(parents=True, exist_ok=True)

# Download the dataset to the specified destination
print(f"Downloading dataset '{dataset_slug}' to '{destination_path}'...")
api.dataset_download_files(dataset_slug, path=destination_path, unzip=True)
print("Download complete.")
# Out:
# Downloading dataset 'msambare/fer2013' to 'fer2013_data'...
# Dataset URL: https://www.kaggle.com/datasets/msambare/fer2013
# Download complete.

# %% [markdown]
#  # Data Preparation & Augmentation

# %%
# OLD
IMG_SIZE = 48
BATCH_SIZE = 64
train_dir = "fer2013_data/train"
test_dir = "fer2013_data/test"

# 1. Create a single generator for both training and validation
#    and add the validation_split argument.
train_val_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    validation_split=0.2
)

# The test data generator remains separate and does not need a split.
test_datagen = ImageDataGenerator(rescale=1.0/255)

# 2. Create the training generator using the 'training' subset
train_generator = train_val_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    color_mode="grayscale",
    class_mode="categorical",
    subset='training' # Specify this is the training subset
)

# 3. Create the validation generator using the 'validation' subset
validation_generator = train_val_datagen.flow_from_directory(
    train_dir, # Use the same directory as the training generator
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    color_mode="grayscale",
    class_mode="categorical",
    subset='validation' # Specify this is the validation subset
)

# 4. The test generator is created from the separate test directory
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    color_mode="grayscale",
    class_mode="categorical"
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# New
train_generator = train_aug.flow_from_directory(
    'dataset/train',
    target_size=(img_height, img_width),
    color_mode='grayscale',
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2916558874.py in <cell line: 0>()
#       1 # New
# ----> 2 train_generator = train_aug.flow_from_directory(
#       3     'dataset/train',
#       4     target_size=(img_height, img_width),
#       5     color_mode='grayscale',
#
# NameError: name 'train_aug' is not defined

# %% [markdown]
# # Viewing training images from dataset

# %%
plt.style.use('ggplot')

# Get a batch of images and labels from the train_generator
images, labels = next(train_generator)

plt.figure(figsize=(12, 12))
for i in range(16):  # Displaying the first 16 images
    plt.subplot(4, 4, i + 1)
    # images[i] is expected to have shape (48, 48, 1) for grayscale
    plt.imshow(images[i].reshape((48, 48)), cmap="gray")
    plt.axis('off')
    plt.tight_layout()

plt.show()

# %% [markdown]
# # Print how many samples are in dataset

# %%
print("Train samples:", train_generator.samples)
print("Test samples:", test_generator.samples)
# Out:
# Train samples: 22968
# Test samples: 7178

# %% [markdown]
# # Define CNN Model

# %% [markdown]
# ### Newer model with  2 conv2d layers in each block

# %%
# Image parameters
img_height, img_width = 48, 48
batch_size = 64
initial_lr = 5e-4
weight_decay = 1e-4   # L2
num_classes = 7       # FER2013
epochs = 50

model = Sequential([
    # --- Block 1 (Deeper and Wider) ---
    Conv2D(64, (3, 3), padding='same', input_shape=(img_height, img_width, 1)),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(64, (3, 3), padding='same'), # Added second Conv2D layer
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.3), # Adjusted dropout

    # --- Block 2 (Deeper and Wider) ---
    Conv2D(128, (3, 3), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(128, (3, 3), padding='same'), # Added second Conv2D layer
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.4), # Adjusted dropout

    # --- Block 3 (Deeper and Wider) ---
    Conv2D(256, (3, 3), padding='same'),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(256, (3, 3), padding='same'), # Added second Conv2D layer
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.5), # Adjusted dropout

    # --- Classifier Head ---
    Flatten(),
    Dense(256), # Increased Dense layer size
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),

    # Output Layer
    Dense(train_generator.num_classes, activation='softmax')
])

# Compile with a slightly higher initial learning rate for use with a scheduler
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 48, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 24, 24, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 24, 24, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     2,359,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,510,215 (13.39 MB)
#  Trainable params: 3,507,911 (13.38 MB)
#  Non-trainable params: 2,304 (9.00 KB)

# %% [markdown]
# ### Model with 58-62 % validation _accuracy

# %%
# Image parameters
img_height = 48
img_width = 48
batch_size = 64


model = Sequential([

    # --- Block 1 ---
    # Input: 48x48x1 -> Output: 48x48x32 W
    Conv2D(32, (3,3), padding='same', input_shape=(img_height, img_width, 1)),
    BatchNormalization(),
    Activation('relu'), # Apply activation after batch norm

    # Input: 48x48x32 -> Output: 24x24x32
    MaxPooling2D(pool_size=(2,2)), # Pool after the first block


    # --- Block 2 ---
    # Input: 24x24x32 -> Output: 24x24x64
    Conv2D(64, (3,3), padding='same'),
    BatchNormalization(),
    Activation('relu'),

    Conv2D(64, (3,3), padding='same'),
    BatchNormalization(),
    Activation('relu'),

    # Input: 24x24x64 -> Output: 12x12x64
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.25),

    # --- Block 3 ---
    # Input: 12x12x64 -> Output: 12x12x128
    Conv2D(128, (3,3), padding='same'),
    BatchNormalization(),
    Activation('relu'),

    # Input: 12x12x128 -> Output: 6x6x128
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.25),

    # --- Classifier Head ---
    Flatten(), # Flattens the 6x6x128 feature map

    Dense(128),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5), # Strong dropout for the dense layer

    Dense(train_generator.num_classes, activation='softmax')
])
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'],
              )

model.summary()

# %% [markdown]
# # Callback function for Plateau

# %%
lr_reduction = ReduceLROnPlateau(
    monitor='val_loss',   # Metric to watch
    patience=5,           # Number of epochs with no improvement before reducing
    factor=0.5,           # Multiply learning rate by this factor
    min_lr=1e-7,          # Lower bound for the learning rate
    verbose =1            # Print messages when LR changes
)

# %% [markdown]
# # Early Stopping

# %%
early_stop = EarlyStopping(
    monitor='val_loss',       # What to monitor
    patience=8,               # Stop after 8 epochs of no improvement
    restore_best_weights=True # Roll back to best model
)

# %% [markdown]
# # Callback for saving model weights

# %%
# Define the callback
checkpoint_callback = ModelCheckpoint(
    filepath='model_weights.weights.h5', # Changed the filepath to end with .weights.h5
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

# %% [markdown]
# #  Removing Class Imbalance

# %%
from sklearn.utils import class_weight
import numpy as np

class_weights = class_weight.compute_class_weight(
    'balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)
class_weights = dict(enumerate(class_weights))

# %% [markdown]
# # Training

# %%
EPOCHS = 50

history = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=EPOCHS,
    callbacks =[  checkpoint_callback],
    # class_weight=class_weights
)
# Out:
# Epoch 1/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.2226 - loss: 2.1349
# Epoch 1: val_accuracy improved from -inf to 0.21287, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 34s 95ms/step - accuracy: 0.2227 - loss: 2.1345 - val_accuracy: 0.2129 - val_loss: 1.8871
# Epoch 2/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.3273 - loss: 1.7346
# Epoch 2: val_accuracy improved from 0.21287 to 0.42547, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.3273 - loss: 1.7344 - val_accuracy: 0.4255 - val_loss: 1.5053
# Epoch 3/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4225 - loss: 1.5018
# Epoch 3: val_accuracy improved from 0.42547 to 0.43160, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.4225 - loss: 1.5017 - val_accuracy: 0.4316 - val_loss: 1.5290
# Epoch 4/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4806 - loss: 1.3648
# Epoch 4: val_accuracy improved from 0.43160 to 0.43355, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.4806 - loss: 1.3648 - val_accuracy: 0.4335 - val_loss: 1.5816
# Epoch 5/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5078 - loss: 1.2978
# Epoch 5: val_accuracy improved from 0.43355 to 0.53149, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 64ms/step - accuracy: 0.5078 - loss: 1.2978 - val_accuracy: 0.5315 - val_loss: 1.2222
# Epoch 6/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5224 - loss: 1.2519
# Epoch 6: val_accuracy did not improve from 0.53149
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.5224 - loss: 1.2519 - val_accuracy: 0.5283 - val_loss: 1.2312
# Epoch 7/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5286 - loss: 1.2377
# Epoch 7: val_accuracy did not improve from 0.53149
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.5286 - loss: 1.2377 - val_accuracy: 0.5059 - val_loss: 1.3277
# Epoch 8/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5439 - loss: 1.1978
# Epoch 8: val_accuracy improved from 0.53149 to 0.57314, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 22s 62ms/step - accuracy: 0.5439 - loss: 1.1978 - val_accuracy: 0.5731 - val_loss: 1.1188
# Epoch 9/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5594 - loss: 1.1668
# Epoch 9: val_accuracy did not improve from 0.57314
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 64ms/step - accuracy: 0.5594 - loss: 1.1668 - val_accuracy: 0.5724 - val_loss: 1.1204
# Epoch 10/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5640 - loss: 1.1564
# Epoch 10: val_accuracy improved from 0.57314 to 0.57328, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.5640 - loss: 1.1564 - val_accuracy: 0.5733 - val_loss: 1.1292
# Epoch 11/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5792 - loss: 1.1270
# Epoch 11: val_accuracy improved from 0.57328 to 0.59989, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.5792 - loss: 1.1270 - val_accuracy: 0.5999 - val_loss: 1.0717
# Epoch 12/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5797 - loss: 1.1205
# Epoch 12: val_accuracy did not improve from 0.59989
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.5797 - loss: 1.1206 - val_accuracy: 0.5846 - val_loss: 1.1005
# Epoch 13/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5904 - loss: 1.0911
# Epoch 13: val_accuracy did not improve from 0.59989
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 65ms/step - accuracy: 0.5904 - loss: 1.0911 - val_accuracy: 0.5844 - val_loss: 1.1056
# Epoch 14/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5955 - loss: 1.0765
# Epoch 14: val_accuracy improved from 0.59989 to 0.60797, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.5955 - loss: 1.0766 - val_accuracy: 0.6080 - val_loss: 1.0318
# Epoch 15/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5932 - loss: 1.0740
# Epoch 15: val_accuracy did not improve from 0.60797
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.5932 - loss: 1.0740 - val_accuracy: 0.5773 - val_loss: 1.1921
# Epoch 16/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5918 - loss: 1.0698
# Epoch 16: val_accuracy did not improve from 0.60797
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.5919 - loss: 1.0698 - val_accuracy: 0.6046 - val_loss: 1.0492
# Epoch 17/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6075 - loss: 1.0398
# Epoch 17: val_accuracy improved from 0.60797 to 0.61925, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 65ms/step - accuracy: 0.6075 - loss: 1.0399 - val_accuracy: 0.6193 - val_loss: 1.0043
# Epoch 18/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6079 - loss: 1.0439
# Epoch 18: val_accuracy did not improve from 0.61925
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 25s 71ms/step - accuracy: 0.6079 - loss: 1.0439 - val_accuracy: 0.5997 - val_loss: 1.0997
# Epoch 19/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6062 - loss: 1.0390
# Epoch 19: val_accuracy did not improve from 0.61925
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.6062 - loss: 1.0390 - val_accuracy: 0.6098 - val_loss: 1.0311
# Epoch 20/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6141 - loss: 1.0179
# Epoch 20: val_accuracy did not improve from 0.61925
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.6141 - loss: 1.0179 - val_accuracy: 0.5795 - val_loss: 1.1451
# Epoch 21/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6219 - loss: 1.0054
# Epoch 21: val_accuracy improved from 0.61925 to 0.62120, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 64ms/step - accuracy: 0.6219 - loss: 1.0055 - val_accuracy: 0.6212 - val_loss: 1.0156
# Epoch 22/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6178 - loss: 1.0078
# Epoch 22: val_accuracy did not improve from 0.62120
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.6178 - loss: 1.0078 - val_accuracy: 0.6160 - val_loss: 1.0446
# Epoch 23/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6279 - loss: 0.9994
# Epoch 23: val_accuracy did not improve from 0.62120
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 64ms/step - accuracy: 0.6279 - loss: 0.9994 - val_accuracy: 0.6043 - val_loss: 1.0906
# Epoch 24/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6243 - loss: 0.9918
# Epoch 24: val_accuracy improved from 0.62120 to 0.63249, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 65ms/step - accuracy: 0.6243 - loss: 0.9918 - val_accuracy: 0.6325 - val_loss: 0.9933
# Epoch 25/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6258 - loss: 0.9875
# Epoch 25: val_accuracy did not improve from 0.63249
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.6258 - loss: 0.9875 - val_accuracy: 0.6223 - val_loss: 1.0538
# Epoch 26/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6342 - loss: 0.9700
# Epoch 26: val_accuracy did not improve from 0.63249
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.6342 - loss: 0.9700 - val_accuracy: 0.6102 - val_loss: 1.1251
# Epoch 27/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6425 - loss: 0.9512
# Epoch 27: val_accuracy did not improve from 0.63249
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 64ms/step - accuracy: 0.6425 - loss: 0.9513 - val_accuracy: 0.6124 - val_loss: 1.0515
# Epoch 28/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6414 - loss: 0.9540
# Epoch 28: val_accuracy did not improve from 0.63249
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 40s 62ms/step - accuracy: 0.6414 - loss: 0.9540 - val_accuracy: 0.6286 - val_loss: 1.0111
# Epoch 29/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6406 - loss: 0.9589
# Epoch 29: val_accuracy improved from 0.63249 to 0.63834, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.6406 - loss: 0.9589 - val_accuracy: 0.6383 - val_loss: 0.9503
# Epoch 30/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6399 - loss: 0.9516
# Epoch 30: val_accuracy did not improve from 0.63834
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.6399 - loss: 0.9516 - val_accuracy: 0.6159 - val_loss: 1.0595
# Epoch 31/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6471 - loss: 0.9316
# Epoch 31: val_accuracy did not improve from 0.63834
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.6471 - loss: 0.9316 - val_accuracy: 0.6088 - val_loss: 1.0769
# Epoch 32/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6531 - loss: 0.9271
# Epoch 32: val_accuracy improved from 0.63834 to 0.64976, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.6531 - loss: 0.9272 - val_accuracy: 0.6498 - val_loss: 0.9434
# Epoch 33/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6581 - loss: 0.9122
# Epoch 33: val_accuracy did not improve from 0.64976
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.6581 - loss: 0.9122 - val_accuracy: 0.6390 - val_loss: 0.9656
# Epoch 34/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6522 - loss: 0.9152
# Epoch 34: val_accuracy did not improve from 0.64976
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.6523 - loss: 0.9152 - val_accuracy: 0.6333 - val_loss: 1.0132
# Epoch 35/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6655 - loss: 0.9014
# Epoch 35: val_accuracy improved from 0.64976 to 0.65408, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.6654 - loss: 0.9014 - val_accuracy: 0.6541 - val_loss: 0.9532
# Epoch 36/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6669 - loss: 0.8881
# Epoch 36: val_accuracy did not improve from 0.65408
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.6669 - loss: 0.8881 - val_accuracy: 0.6411 - val_loss: 0.9814
# Epoch 37/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6614 - loss: 0.8940
# Epoch 37: val_accuracy did not improve from 0.65408
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.6614 - loss: 0.8940 - val_accuracy: 0.6335 - val_loss: 1.0017
# Epoch 38/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6624 - loss: 0.8858
# Epoch 38: val_accuracy improved from 0.65408 to 0.65575, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.6624 - loss: 0.8858 - val_accuracy: 0.6558 - val_loss: 0.9391
# Epoch 39/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6646 - loss: 0.8906
# Epoch 39: val_accuracy did not improve from 0.65575
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 22s 62ms/step - accuracy: 0.6646 - loss: 0.8906 - val_accuracy: 0.6287 - val_loss: 1.0287
# Epoch 40/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6680 - loss: 0.8897
# Epoch 40: val_accuracy did not improve from 0.65575
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 22s 62ms/step - accuracy: 0.6680 - loss: 0.8897 - val_accuracy: 0.6447 - val_loss: 0.9931
# Epoch 41/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6676 - loss: 0.8782
# Epoch 41: val_accuracy improved from 0.65575 to 0.65729, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.6676 - loss: 0.8782 - val_accuracy: 0.6573 - val_loss: 0.9320
# Epoch 42/50
# 358/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6685 - loss: 0.8746
# Epoch 42: val_accuracy did not improve from 0.65729
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.6685 - loss: 0.8746 - val_accuracy: 0.6259 - val_loss: 1.0486
# Epoch 43/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6774 - loss: 0.8750
# Epoch 43: val_accuracy did not improve from 0.65729
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.6774 - loss: 0.8750 - val_accuracy: 0.6290 - val_loss: 1.0172
# Epoch 44/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6746 - loss: 0.8662
# Epoch 44: val_accuracy did not improve from 0.65729
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.6746 - loss: 0.8662 - val_accuracy: 0.6159 - val_loss: 1.0603
# Epoch 45/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6780 - loss: 0.8564
# Epoch 45: val_accuracy did not improve from 0.65729
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.6780 - loss: 0.8564 - val_accuracy: 0.6360 - val_loss: 1.0368
# Epoch 46/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6710 - loss: 0.8715
# Epoch 46: val_accuracy did not improve from 0.65729
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 41s 64ms/step - accuracy: 0.6710 - loss: 0.8714 - val_accuracy: 0.6551 - val_loss: 0.9659
# Epoch 47/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6843 - loss: 0.8363
# Epoch 47: val_accuracy did not improve from 0.65729
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.6843 - loss: 0.8363 - val_accuracy: 0.6478 - val_loss: 1.0231
# Epoch 48/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6819 - loss: 0.8463
# Epoch 48: val_accuracy improved from 0.65729 to 0.66314, saving model to model_weights.weights.h5
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 24s 66ms/step - accuracy: 0.6819 - loss: 0.8463 - val_accuracy: 0.6631 - val_loss: 0.9183
# Epoch 49/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6866 - loss: 0.8338
# Epoch 49: val_accuracy did not improve from 0.66314
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 65ms/step - accuracy: 0.6866 - loss: 0.8338 - val_accuracy: 0.6534 - val_loss: 0.9721
# Epoch 50/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6896 - loss: 0.8213
# Epoch 50: val_accuracy did not improve from 0.66314
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.6896 - loss: 0.8214 - val_accuracy: 0.6312 - val_loss: 1.0444

# %% [markdown]
# # Metrics : Accuracy, Precision, Recall, F1-score

# %%
def f1_score(y_true, y_pred):
    y_pred = K.round(y_pred)
    tp = K.sum(K.cast(y_true * y_pred, 'float'), axis=0)
    fp = K.sum(K.cast((1-y_true) * y_pred, 'float'), axis=0)
    fn = K.sum(K.cast(y_true * (1-y_pred), 'float'), axis=0)

    precision = tp / (tp + fp + K.epsilon())
    recall = tp / (tp + fn + K.epsilon())

    f1 = 2 * precision * recall / (precision + recall + K.epsilon())
    return K.mean(f1)

# %% [markdown]
# # Classification Report

# %%
# 1. Get the true labels from the validation generator
# The .classes attribute gives the class index for each sample in order.
validation_labels = validation_generator.classes

# 2. Get the model's predictions for the validation set
# It's good practice to reset the generator before predicting
validation_generator.reset()
pred_probs = model.predict(validation_generator)
# Convert prediction probabilities to class labels
validation_pred_labels = np.argmax(pred_probs, axis=1)

# 3. Create the Confusion Matrix
cm = confusion_matrix(validation_labels, validation_pred_labels)
class_names = list(validation_generator.class_indices.keys())

# 4. Plot the confusion matrix for a more visual analysis
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix for Validation Set')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

# 5. Print the Classification Report
# This provides precision, recall, and f1-score for each class.
print("Classification Report for Validation Set\n")
print(classification_report(validation_labels, validation_pred_labels, target_names=class_names))
# Out:
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 10s 92ms/step
# Classification Report for Validation Set
#
#               precision    recall  f1-score   support
#
#        angry       0.13      0.13      0.13       799
#      disgust       0.00      0.00      0.00        87
#         fear       0.15      0.07      0.10       819
#        happy       0.25      0.25      0.25      1443
#      neutral       0.17      0.27      0.21       993
#          sad       0.17      0.14      0.16       966
#     surprise       0.12      0.13      0.12       634
#
#     accuracy                           0.18      5741
#    macro avg       0.14      0.14      0.14      5741
# weighted avg       0.17      0.18      0.17      5741

# %% [markdown]
# # Visualizing the model

# %%
# prompt: Write me a code to interactivaly visualize the Neural Network architecture of the above model

if not os.path.exists('results'):
  os.mkdir("results")

model_plot_path = 'results/model_plot.png'
# Generate and save the model plot
plot_model(model, to_file=model_plot_path, show_shapes=True, show_layer_names=True)

# Display the generated image in the notebook
Image(filename=model_plot_path)

# %% [markdown]
# # Saving the Model

# %%
model.save("results/emotion_model.keras")
print("Model saved successfully!")
# Out:
# Model saved successfully!

# %% [markdown]
# # Plotting the graphs (Accuracy/Loss Curves Visualization)

# %% [markdown]
# ### Plot the train and validation loss

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig("results/training_validation_loss.png")
plt.show()

# %% [markdown]
# ### Plot the train and validation accuracy

# %%
# Plot the train and validation accuracy
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, train_acc, 'ro', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig("results/training_validation_accuracy.png")
plt.show()

# %% [markdown]
# # Converting results to zip for download

# %%
import shutil
# ====================
#  ZIP RESULTS
# ====================
shutil.make_archive("results", 'zip', "results")
print("✅ Training complete. Results saved to results.zip")
# Out:
# ✅ Training complete. Results saved to results.zip

# %% [markdown]
# # Converting images to testing data set

# %%
import os
from PIL import Image

# --- SETTINGS ---
input_folder = "my_images"  # folder containing your images (unsorted)
output_folder = "myimages"  # where to save processed images
target_size = (48, 48)  # for FER-style datasets
to_grayscale = True  # set False if you want to keep RGB

# --- CREATE OUTPUT FOLDER IF NOT EXISTS ---
os.makedirs(output_folder, exist_ok=True)

# --- PROCESS IMAGES ---
for i, filename in enumerate(os.listdir(input_folder)):
    if filename.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".gif")):
        img_path = os.path.join(input_folder, filename)
        try:
            img = Image.open(img_path)

            # Convert to grayscale if needed
            if to_grayscale:
                img = img.convert("L")  # "L" = 8-bit pixels, black and white

            # Resize to target size
            img = img.resize(target_size)

            # Save to output folder
            save_path = os.path.join(output_folder, f"img_{i+1}.jpg")
            img.save(save_path)

            print(f"Processed: {filename} → {save_path}")
        except Exception as e:
            print(f"Error processing {filename}: {e}")

print("\n✅ All images processed and saved to:", output_folder)
# Out:
# Processed: surprised.jpg → myimages/img_1.jpg
# Processed: neutral.jpg → myimages/img_2.jpg
# Processed: happy.jpg → myimages/img_3.jpg
# Processed: angry.jpg → myimages/img_4.jpg
# Processed: fear.jpg → myimages/img_5.jpg
# Processed: disgust.jpg → myimages/img_6.jpg
# Processed: sad.jpg → myimages/img_7.jpg
#
# ✅ All images processed and saved to: myimages

# %%
from google.colab import runtime
runtime.unassign()
